# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import MultinomialNB
from sklearn import metrics
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
data = pd.read_csv('data2019-04-02 12_48_35.csv')
# data.dropna(axis=0)
data.shape
# Out:
# (120000, 6)

# %%
data.dropna(axis=0)
data.shape
# Out:
# (120000, 6)

# %%
data['container-title'].replace(['Chem. Commun.', 'RSC Adv.','Natural Hazards and Earth System Sciences','J. Mater. Chem. A','Dalton Trans.','JOURNAL OF CIVIL ENGINEERING AND MANAGEMENT'], 
                      ['Chemical Communications', 'RSC Advances','Natural Hazards and Earth System Science','Journal of Materials Chemistry A','Dalton Transactions','Journal of Civil Engineering and Management'], inplace=True)

# %%
journals = []

for i in data['container-title']:
    if not i in journals:
        journals.append(i)

journals
# Out:
# ['RSC Advances',
#  'Journal of Materials Chemistry A',
#  'Phys. Chem. Chem. Phys.',
#  'Physical Chemistry Chemical Physics',
#  'J. Mater. Chem. C',
#  'Journal of Materials Chemistry C',
#  'Australian Journal of Chemistry',
#  'Journal of Glaciology',
#  'Nanoscale',
#  'Chemical Communications',
#  'Australian Journal of Physics',
#  'Clay Minerals',
#  'Journal of Applied Crystallography',
#  'Dalton Transactions']

# %%
journalsdict = dict()

for indx, i in enumerate(journals):
    journalsdict[i] = indx
    
journalsdict
# Out:
# {'RSC Advances': 0,
#  'Journal of Materials Chemistry A': 1,
#  'Phys. Chem. Chem. Phys.': 2,
#  'Physical Chemistry Chemical Physics': 3,
#  'J. Mater. Chem. C': 4,
#  'Journal of Materials Chemistry C': 5,
#  'Australian Journal of Chemistry': 6,
#  'Journal of Glaciology': 7,
#  'Nanoscale': 8,
#  'Chemical Communications': 9,
#  'Australian Journal of Physics': 10,
#  'Clay Minerals': 11,
#  'Journal of Applied Crystallography': 12,
#  'Dalton Transactions': 13}

# %%
data['y'] = data['container-title'].apply(lambda x : journalsdict[x])
data.head()
# Out:
#    Unnamed: 0                 DOI  \
# 0           0  10.1039/c3ra46913a
# 1           1  10.1039/c3ra46462h
# 2           2  10.1039/c3ra46915h
# 3           3  10.1039/c3ra46453a
# 4           4  10.1039/c3ra46967k
#
#                                           cleanTitle container-title  \
# 0  esr study spin adducts three analogues depmpo ...    RSC Advances
# 1  reactions mono bicyclic enol ethers i–hydroper...    RSC Advances
# 2  copper catalyzed oxidative cascade coupling n ...    RSC Advances
# 3  catalytic wet peroxide oxidation phenol ch ch ...    RSC Advances
# 4  supramolecular analyte recognition experiment ...    RSC Advances
#
#                                        cleanAbstract  is-referenced-by-count  \
# 0  paverage geometries nitroxide adducts various ...                       1
# 1  preactions mono bicyclic enol ethers isubsub–h...                       7
# 2  pan oxidative cascade coupling reaction italic...                      19
# 3  punder ambient temperature atmospheric pressur...                      10
# 4  psynergy experimental theoretical tools made s...                       5
#
#    y
# 0  0
# 1  0
# 2  0
# 3  0
# 4  0

# %% [markdown]
# ### Randomizing data

# %%
data = data.reindex(np.random.permutation(data.index))
data = data.reindex(np.random.permutation(data.index))
data = data.reindex(np.random.permutation(data.index))
data
# Out:
#         Unnamed: 0                            DOI  \
# 116762         762             10.1039/c4dt02234c
# 87029           29               10.1071/ph850497
# 52887          887          10.3189/2015jog15j116
# 91581          581  10.1180/claymin.2015.050.3.12
# 84841          841               10.1071/ph700823
# 112228         228             10.1039/c4dt00161c
# 86509          509               10.1071/ph951055
# 44877          877                10.1071/ch03263
# 44669          669                10.1071/ch03124
# 36024           24             10.1039/c3tc32170c
# 5671           671             10.1039/c3ra46651e
# 73053           53             10.1039/c3cc47942k
# 103567         567      10.1107/s0021889898011157
# 43828          828                10.1071/ch03160
# 99193          193        10.1180/000985599546073
# 106945         945      10.1107/s0021889898001629
# 52832          832          10.3189/2015jog14j147
# 24204          204             10.1039/c4cp00176a
# 44952          952                10.1071/ch14396
# 13841          841             10.1039/c4ta04196h
# 110290         290             10.1039/c4dt00500g
# 47066           66                10.1071/ch13185
# 22439          439             10.1039/c4cp01537a
# 116623         623             10.1039/c4dt01617c
# 69118          118             10.1039/c3nr06599e
# 14419          419             10.1039/c4ta00931b
# 46327          327                10.1071/ch13335
# 55670          670          10.3189/2014jog14j040
# 74503          503             10.1039/c4cc00440j
# 101779         779      10.1107/s0021889882011789
# ...            ...                            ...
# 93361          361  10.1180/claymin.2008.043.3.12
# 51278          278     10.3189/172756503781830863
# 67796          796             10.1039/c4nr03962a
# 119089          89             10.1039/c4dt00211c
# 116127         127             10.1039/c4dt00292j
# 104507         507      10.1107/s002188980100468x
# 55502          502     10.3189/172756507782202838
# 9116           116             10.1039/c3ra46239k
# 2658           658             10.1039/c4ra01608d
# 93757          757  10.1180/claymin.1985.020.1.08
# 8380           380             10.1039/c4ra00436a
# 35982          982             10.1039/c5tc00028a
# 2834           834             10.1039/c4ra00823e
# 17067           67             10.1039/c3ta14692h
# 78632          632             10.1039/c4cc03092c
# 71991          991             10.1039/c4cc03184a
# 2611           611             10.1039/c4ra00623b
# 40893          893                10.1071/ch14353
# 31800          800             10.1039/c4tc02362e
# 97335          335       10.1180/0009855033830104
# 11732          732             10.1039/c4ta01869a
# 61307          307             10.1039/c4nr00951g
# 117037          37             10.1039/c3dt53207k
# 66498          498             10.1039/c4nr02023e
# 24289          289             10.1039/c4cp01136h
# 105757         757      10.1107/s0021889897002185
# 6737           737             10.1039/c4ra01595a
# 119231         231             10.1039/c3dt53637h
# 70606          606             10.1039/c4cc01670j
# 46712          712                10.1071/ch13693
#
#                                                cleanTitle  \
# 116762  converting dual mode ypo yb tb nanocrystals sy...
# 87029   solving crystal structures powder diffraction ...
# 52887   assessment ice flow dynamics zone close calvin...
# 91581   kaolin acoculco puebla mexico raw material min...
# 84841   multilevel formalism neutron elastic scatterin...
# 112228  equiatomic intermetallic compounds ytx ni ir x...
# 86509                           newtonian quantum gravity
# 44877   edf density functional predicting molecular vi...
# 44669   biomimetic honeycomb structured surfaces forme...
# 36024   novel series quaternary fluoride nanocrystals ...
# 5671    temperature dependent self assembled motif tra...
# 73053   peroxynitrite chemistry derived nitric oxide r...
# 103567  combination energy minimizations rigid body ri...
# 43828   chiral resolution hexaamine cobalt iii cages s...
# 99193   precursor support interactions preparation sep...
# 106945  structural change caused substitution nd sm nd...
# 52832   modern glacier velocities across icefield rang...
# 24204     optical three dimensional coherent spectroscopy
# 44952   small angle x ray scattering discerning macrom...
# 13841   infiltrative coating linicomno microspheres la...
# 110290  unique amino cyclopropane carboxylate cupric c...
# 47066   homo heteroleptic quinaldinolate complexes ele...
# 22439   different aggregation dynamics benzene–water m...
# 116623  exploring mechanism grignard metathesis polyme...
# 69118   biodegradable nanoassemblies piperlongumine di...
# 14419   facile fabrication α feooh nanorodrgo composit...
# 46327   situ alloying dynamics phase morphology binary...
# 55670   high variability climate surface mass balance ...
# 74503   one pot synthesis nitrogen sulfur co doped gra...
# 101779  experimental computed hrem images structure de...
# ...                                                   ...
# 93361   fe intercalationdeposition vermiculites intera...
# 51278   catastrophic ice shelf break ice shelf fragmen...
# 67796   biocompatible mannosylated endosomal escape na...
# 119089  structural diversity photoluminescent properti...
# 116127  sensitisation eu iii tb iii based luminescence...
# 104507  polycapillary optic–source combinations protei...
# 55502   loading path specimen thickness affect brittle...
# 9116    specific cu ii detection using novel tricarbaz...
# 2658    template free syntheses cds microspheres compo...
# 93757   l alteration lateritique debutante des pyroxen...
# 8380    theoretical study effect different substituent...
# 35982   realization inpzns quantum dots green amber re...
# 2834       polymeric foams functional nanocomposite cells
# 17067                theory mass transport sodium alanate
# 78632   microwave assisted preparation nucleoside phos...
# 71991   optical control bioactive ligands supramolecul...
# 2611    thermally derived liquid phase involving multi...
# 40893   chitosan–zinc oxide nanoparticles combined dis...
# 31800   non uniform distribution dopant iron ions tio ...
# 97335                     surface microtopography sudoite
# 11732   zeolite encapsulated ni ii cu ii complexes tet...
# 61307   nano frost array technique prepare nanoporous ...
# 117037  key role nanoparticle seeds site selective gro...
# 66498   morphology control luminescence energy transfe...
# 24289   spectral evidence hydrogen induced reversible ...
# 105757  speckle structure small angle coherent x ray s...
# 6737    novel polyoxadiazoles non coplanar ortho linke...
# 119231  colorimetric “ naked eye ” cu ii chemosensor p...
# 70606   switching sensitive glucose oxidase bioelectro...
# 46712   synthesis photo physical electrochemical prope...
#
#                            container-title  \
# 116762                 Dalton Transactions
# 87029        Australian Journal of Physics
# 52887                Journal of Glaciology
# 91581                        Clay Minerals
# 84841        Australian Journal of Physics
# 112228                 Dalton Transactions
# 86509        Australian Journal of Physics
# 44877      Australian Journal of Chemistry
# 44669      Australian Journal of Chemistry
# 36024                    J. Mater. Chem. C
# 5671                          RSC Advances
# 73053              Chemical Communications
# 103567  Journal of Applied Crystallography
# 43828      Australian Journal of Chemistry
# 99193                        Clay Minerals
# 106945  Journal of Applied Crystallography
# 52832                Journal of Glaciology
# 24204              Phys. Chem. Chem. Phys.
# 44952      Australian Journal of Chemistry
# 13841     Journal of Materials Chemistry A
# 110290                 Dalton Transactions
# 47066      Australian Journal of Chemistry
# 22439              Phys. Chem. Chem. Phys.
# 116623                 Dalton Transactions
# 69118                            Nanoscale
# 14419     Journal of Materials Chemistry A
# 46327      Australian Journal of Chemistry
# 55670                Journal of Glaciology
# 74503              Chemical Communications
# 101779  Journal of Applied Crystallography
# ...                                    ...
# 93361                        Clay Minerals
# 51278                Journal of Glaciology
# 67796                            Nanoscale
# 119089                 Dalton Transactions
# 116127                 Dalton Transactions
# 104507  Journal of Applied Crystallography
# 55502                Journal of Glaciology
# 9116                          RSC Advances
# 2658                          RSC Advances
# 93757                        Clay Minerals
# 8380                          RSC Advances
# 35982     Journal of Materials Chemistry C
# 2834                          RSC Advances
# 17067     Journal of Materials Chemistry A
# 78632              Chemical Communications
# 71991              Chemical Communications
# 2611                          RSC Advances
# 40893      Australian Journal of Chemistry
# 31800     Journal of Materials Chemistry C
# 97335                        Clay Minerals
# 11732     Journal of Materials Chemistry A
# 61307                            Nanoscale
# 117037                 Dalton Transactions
# 66498                            Nanoscale
# 24289              Phys. Chem. Chem. Phys.
# 105757  Journal of Applied Crystallography
# 6737                          RSC Advances
# 119231                 Dalton Transactions
# 70606              Chemical Communications
# 46712      Australian Journal of Chemistry
#
#                                             cleanAbstract  \
# 116762  pthe dual mode luminescence yposubsub nanocrys...
# 87029   high resolution powder data neutron x ray sync...
# 52887   jats titleabstractjats title investigate relat...
# 91581   jats titleabstractjats title present study det...
# 84841   extension feshbach porter weisskopf formalism ...
# 112228  pthe equiatomic tinisi type tetrelides ytx spa...
# 86509   develop nonlinear quantum theory newtonian gra...
# 44877   majority calculations molecular vibrational sp...
# 44669   report preparation biomimetic honeycomb struct...
# 36024   pa straightforward wet chemical approach phase...
# 5671    pthe mechanism irreversible structure transiti...
# 73053   pnew peroxynitrite–copper chemistry ensues ita...
# 103567  crystal structure yellow pigment dihydroxybenz...
# 43828   chiral resolution cobalt cage complexes co din...
# 99193   jats titleabstractjats title naturally occurri...
# 106945  structural change caused substitution nd sm pe...
# 52832   jats titleabstractjats title new high resoluti...
# 24204   poptical multdimensional coherent spectroscopy...
# 44952   role small angle x ray scattering saxs structu...
# 13841   player structured litiosubsub coating layer bu...
# 110290  pexploiting self assembly cu closubsub subsub ...
# 47066   three new zinc quinaldinolate complexes obtain...
# 22439   pthe differences molecular aggregations benzen...
# 116623  pin study investigated computationally mechani...
# 69118   ppiperlongumine rendered polymeric micelles fo...
# 14419   p italicin situitalic fabrication deposition α...
# 46327   situ alloying polypropylene pp polystyrene ps ...
# 55670   jats titleabstractjats title ice rises play ke...
# 74503   pnovel n co doped graphene nsg prepared anneal...
# 101779  monoclinic gdjats subjats subsiojats subjats s...
# ...                                                   ...
# 93361   jats titleabstractjats title fejats sup jats s...
# 51278   jats titleabstractjats title two disintegratio...
# 67796   pmannosylated nanoparticles capable delivering...
# 119089  ptwo series cd sciisc cps based two positional...
# 116127  pin ir sciiisc eu sciiisc ir sciiisc tb sciiis...
# 104507  work paper systematic study application collim...
# 55502   jats titleabstractjats title compressive exper...
# 9116    pa novel tricarbazolyl tristriazolotriazine sp...
# 2658    pa one pot template free solvothermal method s...
# 93757   jats titleresumejats title l altération latéri...
# 8380    pthe high quantum yield boldbold compared bold...
# 35982   peco friendly inpzns quantum dots qds synthesi...
# 2834    pelastomeric foams controlled cell size compos...
# 17067   pa quantitative model mass transport developed...
# 78632   pmicrowave assisted phosphitylation nucleoside...
# 71991   paddressing whole protein bacterial immobiliza...
# 2611    pmultiphase cu inga sesubsub nanoparticles con...
# 40893   study chitosan–zinc oxide nanoparticles used a...
# 31800   pthe phenomenon ‘ self purification ’ real mec...
# 97335   jats titleabstractjats title gold decoration t...
# 11732   pmetal hydrazone complexes entrapped cavities ...
# 61307   pwe demonstrate simple novel approach fabricat...
# 117037  pone sided silver growth transformed two sided...
# 66498   pgrowth mechanism photoluminescence properties...
# 24289   padsorption hydrogen titania supported rh nano...
# 105757  small angle coherent x ray scattering measurem...
# 6737    pa novel class polyoxadiazole membranes contai...
# 119231  pa highly selective sensitive colorimetric cus...
# 70606   pwe switched osubsub sensitive glucose oxidase...
# 46712   chiral dendritic architectures benzothiazole s...
#
#         is-referenced-by-count   y
# 116762                      23  13
# 87029                       22  10
# 52887                        3   7
# 91581                        4  11
# 84841                        0  10
# 112228                       6  13
# 86509                       27  10
# 44877                       86   6
# 44669                       41   6
# 36024                       14   4
# 5671                         9   0
# 73053                        7   9
# 103567                      18  12
# 43828                       12   6
# 99193                        1  11
# 106945                      11  12
# 52832                        9   7
# 24204                       16   2
# 44952                        2   6
# 13841                       39   1
# 110290                       1  13
# 47066                        0   6
# 22439                        5   2
# 116623                      18  13
# 69118                       14   8
# 14419                       94   1
# 46327                        0   6
# 55670                       18   7
# 74503                      185   9
# 101779                       0  12
# ...                        ...  ..
# 93361                        3  11
# 51278                       94   7
# 67796                       24   8
# 119089                      29  13
# 116127                      23  13
# 104507                      14  12
# 55502                        0   7
# 9116                         4   0
# 2658                        17   0
# 93757                       15  11
# 8380                        10   0
# 35982                       29   5
# 2834                         2   0
# 17067                        4   1
# 78632                        4   9
# 71991                       30   9
# 2611                         3   0
# 40893                        3   6
# 31800                       23   5
# 97335                        1  11
# 11732                       41   1
# 61307                       14   8
# 117037                       1  13
# 66498                        9   8
# 24289                        8   2
# 105757                       7  12
# 6737                         2   0
# 119231                      73  13
# 70606                       22   9
# 46712                        2   6
#
# [120000 rows x 7 columns]

# %% [markdown]
# ### Handle Unicode

# %%
def handleunicode(x):
    try:
        x.decode(encoding='utf-8')
        return x
    except:
        return x

# %%
data['cleanTitle'] = data['cleanTitle'].apply(lambda x : handleunicode(x))
data['cleanAbstract'] = data['cleanAbstract'].apply(lambda x :  handleunicode(x))

data.head()
# Out:
#         Unnamed: 0                            DOI  \
# 116762         762             10.1039/c4dt02234c
# 87029           29               10.1071/ph850497
# 52887          887          10.3189/2015jog15j116
# 91581          581  10.1180/claymin.2015.050.3.12
# 84841          841               10.1071/ph700823
#
#                                                cleanTitle  \
# 116762  converting dual mode ypo yb tb nanocrystals sy...
# 87029   solving crystal structures powder diffraction ...
# 52887   assessment ice flow dynamics zone close calvin...
# 91581   kaolin acoculco puebla mexico raw material min...
# 84841   multilevel formalism neutron elastic scatterin...
#
#                       container-title  \
# 116762            Dalton Transactions
# 87029   Australian Journal of Physics
# 52887           Journal of Glaciology
# 91581                   Clay Minerals
# 84841   Australian Journal of Physics
#
#                                             cleanAbstract  \
# 116762  pthe dual mode luminescence yposubsub nanocrys...
# 87029   high resolution powder data neutron x ray sync...
# 52887   jats titleabstractjats title investigate relat...
# 91581   jats titleabstractjats title present study det...
# 84841   extension feshbach porter weisskopf formalism ...
#
#         is-referenced-by-count   y
# 116762                      23  13
# 87029                       22  10
# 52887                        3   7
# 91581                        4  11
# 84841                        0  10

# %%
#Feature 1 : only title
data["X1"] = data['cleanTitle']
#Feature 2 : only abstract
data["X2"] = data['cleanAbstract']
#Feature 3 : title + abstract
data["X3"] = data.apply(lambda x : str(x["cleanTitle"])+ " " + str(x["cleanAbstract"]), axis=1)
data.head()
# Out:
#         Unnamed: 0                            DOI  \
# 116762         762             10.1039/c4dt02234c
# 87029           29               10.1071/ph850497
# 52887          887          10.3189/2015jog15j116
# 91581          581  10.1180/claymin.2015.050.3.12
# 84841          841               10.1071/ph700823
#
#                                                cleanTitle  \
# 116762  converting dual mode ypo yb tb nanocrystals sy...
# 87029   solving crystal structures powder diffraction ...
# 52887   assessment ice flow dynamics zone close calvin...
# 91581   kaolin acoculco puebla mexico raw material min...
# 84841   multilevel formalism neutron elastic scatterin...
#
#                       container-title  \
# 116762            Dalton Transactions
# 87029   Australian Journal of Physics
# 52887           Journal of Glaciology
# 91581                   Clay Minerals
# 84841   Australian Journal of Physics
#
#                                             cleanAbstract  \
# 116762  pthe dual mode luminescence yposubsub nanocrys...
# 87029   high resolution powder data neutron x ray sync...
# 52887   jats titleabstractjats title investigate relat...
# 91581   jats titleabstractjats title present study det...
# 84841   extension feshbach porter weisskopf formalism ...
#
#         is-referenced-by-count   y  \
# 116762                      23  13
# 87029                       22  10
# 52887                        3   7
# 91581                        4  11
# 84841                        0  10
#
#                                                        X1  \
# 116762  converting dual mode ypo yb tb nanocrystals sy...
# 87029   solving crystal structures powder diffraction ...
# 52887   assessment ice flow dynamics zone close calvin...
# 91581   kaolin acoculco puebla mexico raw material min...
# 84841   multilevel formalism neutron elastic scatterin...
#
#                                                        X2  \
# 116762  pthe dual mode luminescence yposubsub nanocrys...
# 87029   high resolution powder data neutron x ray sync...
# 52887   jats titleabstractjats title investigate relat...
# 91581   jats titleabstractjats title present study det...
# 84841   extension feshbach porter weisskopf formalism ...
#
#                                                        X3
# 116762  converting dual mode ypo yb tb nanocrystals sy...
# 87029   solving crystal structures powder diffraction ...
# 52887   assessment ice flow dynamics zone close calvin...
# 91581   kaolin acoculco puebla mexico raw material min...
# 84841   multilevel formalism neutron elastic scatterin...

# %%
data.head()
# Out:
#         Unnamed: 0                            DOI  \
# 116762         762             10.1039/c4dt02234c
# 87029           29               10.1071/ph850497
# 52887          887          10.3189/2015jog15j116
# 91581          581  10.1180/claymin.2015.050.3.12
# 84841          841               10.1071/ph700823
#
#                                                cleanTitle  \
# 116762  converting dual mode ypo yb tb nanocrystals sy...
# 87029   solving crystal structures powder diffraction ...
# 52887   assessment ice flow dynamics zone close calvin...
# 91581   kaolin acoculco puebla mexico raw material min...
# 84841   multilevel formalism neutron elastic scatterin...
#
#                       container-title  \
# 116762            Dalton Transactions
# 87029   Australian Journal of Physics
# 52887           Journal of Glaciology
# 91581                   Clay Minerals
# 84841   Australian Journal of Physics
#
#                                             cleanAbstract  \
# 116762  pthe dual mode luminescence yposubsub nanocrys...
# 87029   high resolution powder data neutron x ray sync...
# 52887   jats titleabstractjats title investigate relat...
# 91581   jats titleabstractjats title present study det...
# 84841   extension feshbach porter weisskopf formalism ...
#
#         is-referenced-by-count   y  \
# 116762                      23  13
# 87029                       22  10
# 52887                        3   7
# 91581                        4  11
# 84841                        0  10
#
#                                                        X1  \
# 116762  converting dual mode ypo yb tb nanocrystals sy...
# 87029   solving crystal structures powder diffraction ...
# 52887   assessment ice flow dynamics zone close calvin...
# 91581   kaolin acoculco puebla mexico raw material min...
# 84841   multilevel formalism neutron elastic scatterin...
#
#                                                        X2  \
# 116762  pthe dual mode luminescence yposubsub nanocrys...
# 87029   high resolution powder data neutron x ray sync...
# 52887   jats titleabstractjats title investigate relat...
# 91581   jats titleabstractjats title present study det...
# 84841   extension feshbach porter weisskopf formalism ...
#
#                                                        X3
# 116762  converting dual mode ypo yb tb nanocrystals sy...
# 87029   solving crystal structures powder diffraction ...
# 52887   assessment ice flow dynamics zone close calvin...
# 91581   kaolin acoculco puebla mexico raw material min...
# 84841   multilevel formalism neutron elastic scatterin...

# %%
X = data.X1
y = data.y


from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=1, test_size=0.50)

# %%
# examine the object shapes
print(X_train.shape)
print(X_test.shape)

data.describe()
# Out:
# (60000,)
# (60000,)
#           Unnamed: 0  is-referenced-by-count              y
# count  120000.000000           120000.000000  120000.000000
# mean      499.500000               18.445083       6.955250
# std       288.676193               28.624008       4.169519
# min         0.000000                0.000000       0.000000
# 25%       249.750000                5.000000       3.750000
# 50%       499.500000               11.500000       7.500000
# 75%       749.250000               23.000000      10.250000
# max       999.000000             1538.000000      13.000000

# %%
import numpy as np
import matplotlib.pyplot as plt
from matplotlib.colors import ListedColormap
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import make_moons, make_circles, make_classification
from sklearn.neural_network import MLPClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.gaussian_process import GaussianProcessClassifier
from sklearn.gaussian_process.kernels import RBF
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.discriminant_analysis import QuadraticDiscriminantAnalysis

names = ["Nearest Neighbors", "Linear SVM", "RBF SVM", "Gaussian Process",
         "Decision Tree", "Random Forest", "Neural Net", "AdaBoost",
         "Naive Bayes", "QDA"]

classifiers = [
    KNeighborsClassifier(3),
    SVC(kernel="linear", C=0.025),
    SVC(gamma=2, C=1),
    GaussianProcessClassifier(1.0 * RBF(1.0)),
    DecisionTreeClassifier(max_depth=5),
    RandomForestClassifier(max_depth=5, n_estimators=10, max_features=1),
    MLPClassifier(alpha=1),
    AdaBoostClassifier(),
    GaussianNB(),
    QuadraticDiscriminantAnalysis()]


def allModels(vect, model, name):
    try:
        # create document-term matrices using the vectorizer
        X_train_dtm = vect.fit_transform(X_train.values.astype('U'))
        X_test_dtm = vect.transform(X_test)
        print(name)
        # print the number of features that were generated
        print('Features: ', X_train_dtm.shape[1])

        # use Multinomial Naive Bayes to predict the star rating
        nb = model
        nb.fit(X_train_dtm, y_train)
        y_pred_class = nb.predict(X_test_dtm)
        trainAcc = metrics.accuracy_score(y_train, nb.predict(X_train_dtm))
        testAcc =  metrics.accuracy_score(y_test, y_pred_class)
        # Get the training accuracy

        print('Training Accuracy: ', trainAcc)
        # print the accuracy of its predictions
        print('Test Accuracy: ',testAcc)

        return {"model":name, "trainacc": trainAcc, "testacc": testAcc,
                "ytest":X_test_dtm, "ypredict":y_pred_class}
    except:
        return None

# %%
allresults = []

for i in range(len(names)):
    vect = CountVectorizer()
    allresults.append(allModels(vect, classifiers[i], names[i]))
# Out:
# Nearest Neighbors
# Features:  16899
# Training Accuracy:  0.9990333333333333
# Test Accuracy:  0.9893
# Linear SVM
# Features:  16899
# Training Accuracy:  0.8464833333333334
# Test Accuracy:  0.8041833333333334
# RBF SVM
# Features:  16899
# Training Accuracy:  1.0
# Test Accuracy:  0.9973333333333333
# Gaussian Process
# Features:  16899
# Decision Tree
# Features:  16899
# Training Accuracy:  0.197
# Test Accuracy:  0.195
# Random Forest
# Features:  16899
# Training Accuracy:  0.09396666666666667
# Test Accuracy:  0.09203333333333333
# Neural Net
# Features:  16899
# /home/mahmoud/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/multilayer_perceptron.py:564: UserWarning: Training interrupted by user.
#   warnings.warn("Training interrupted by user.")
# Training Accuracy:  0.7789666666666667
# Test Accuracy:  0.7425333333333334
# AdaBoost
# Features:  16899
# Training Accuracy:  0.15851666666666667
# Test Accuracy:  0.15915
# Naive Bayes
# Features:  16899
# QDA
# Features:  16899

# %%
allresults
# Out:
# [{'model': 'Nearest Neighbors',
#   'trainacc': 0.9990333333333333,
#   'testacc': 0.9893,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([ 8,  6, 10, ...,  2,  8,  0])},
#  {'model': 'Linear SVM',
#   'trainacc': 0.8464833333333334,
#   'testacc': 0.8041833333333334,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([ 8,  6, 10, ...,  2,  8,  0])},
#  {'model': 'RBF SVM',
#   'trainacc': 1.0,
#   'testacc': 0.9973333333333333,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([ 8,  6, 10, ...,  2,  8,  0])},
#  None,
#  {'model': 'Decision Tree',
#   'trainacc': 0.197,
#   'testacc': 0.195,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([10, 10, 10, ..., 10, 10, 10])},
#  {'model': 'Random Forest',
#   'trainacc': 0.09396666666666667,
#   'testacc': 0.09203333333333333,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([13, 13, 13, ..., 13, 13, 13])},
#  {'model': 'Neural Net',
#   'trainacc': 0.7789666666666667,
#   'testacc': 0.7425333333333334,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([ 8,  6, 10, ...,  2,  8,  0])},
#  {'model': 'AdaBoost',
#   'trainacc': 0.15851666666666667,
#   'testacc': 0.15915,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([12, 12, 12, ..., 12, 12, 12])},
#  None,
#  None]

# %%
newRes = []
for i in allresults:
    if i is not None:
        newRes.append(i)
newRes
# Out:
# [{'model': 'Nearest Neighbors',
#   'trainacc': 0.9990333333333333,
#   'testacc': 0.9893,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([ 8,  6, 10, ...,  2,  8,  0])},
#  {'model': 'Linear SVM',
#   'trainacc': 0.8464833333333334,
#   'testacc': 0.8041833333333334,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([ 8,  6, 10, ...,  2,  8,  0])},
#  {'model': 'RBF SVM',
#   'trainacc': 1.0,
#   'testacc': 0.9973333333333333,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([ 8,  6, 10, ...,  2,  8,  0])},
#  {'model': 'Decision Tree',
#   'trainacc': 0.197,
#   'testacc': 0.195,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([10, 10, 10, ..., 10, 10, 10])},
#  {'model': 'Random Forest',
#   'trainacc': 0.09396666666666667,
#   'testacc': 0.09203333333333333,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([13, 13, 13, ..., 13, 13, 13])},
#  {'model': 'Neural Net',
#   'trainacc': 0.7789666666666667,
#   'testacc': 0.7425333333333334,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([ 8,  6, 10, ...,  2,  8,  0])},
#  {'model': 'AdaBoost',
#   'trainacc': 0.15851666666666667,
#   'testacc': 0.15915,
#   'ytest': <60000x16899 sparse matrix of type '<class 'numpy.int64'>'
#   	with 597273 stored elements in Compressed Sparse Row format>,
#   'ypredict': array([12, 12, 12, ..., 12, 12, 12])}]

# %%
newRes.append({'model': "SGDClassifier", 
              'trainacc':0.9707666666666667,
               'testacc': 0.9490666666666666})

# %%
ress = pd.DataFrame(newRes)
ind = list(ress.model)
tacc = list(ress.trainacc)
tesac = list(ress.testacc)
ress2 = pd.DataFrame({"TrainAccuracy":tacc, "TestAccuracy":tesac}, index=ind)
ress2
# Out:
#                    TrainAccuracy  TestAccuracy
# Nearest Neighbors       0.999033      0.989300
# Linear SVM              0.846483      0.804183
# RBF SVM                 1.000000      0.997333
# Decision Tree           0.197000      0.195000
# Random Forest           0.093967      0.092033
# Neural Net              0.778967      0.742533
# AdaBoost                0.158517      0.159150
# SGDClassifier           0.970767      0.949067

# %%
ress2.to_csv("ML_training_results.csv", index=False)

# %%
plt.figure(figsize=(20,10))
# plt.bar(ress.model, ress.traina


ress.plot.bar(x='model', y=['trainacc', 'testacc'])
plt.show()

# %%
# from sklearn.metrics import confusion_matrix

# for i in newRes[:1]:
# #     print(i["ytest"])
#     conf_mat = confusion_matrix(i["ytest"].toarray(), np.array(i["ypredict"]))
#     fig, ax = plt.subplots(figsize=(10,10))
#     sns.heatmap(conf_mat, annot=True, fmt='d')
#     plt.ylabel('Actual')
#     plt.xlabel('Predicted')
#     plt.show()

# %%
# import seaborn as sns
# sns.boxplot(x='model_name', y='accuracy', data=cv_df)
# sns.stripplot(x='model_name', y='accuracy', data=cv_df, 
#               size=8, jitter=True, edgecolor="gray", linewidth=2)
# plt.show()
